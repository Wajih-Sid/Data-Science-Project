# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import copy
# %matplotlib inline

sns.set(style="ticks", color_codes=True)


ibm_data = pd.read_csv("HR_IBM.csv")
xyz_data = pd.read_csv("organization.csv")

fields_trim_ibm = ['EmployeeCount', 'Over18', 'EmployeeNumber', 'StandardHours']

ibm_data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  6210.000000  6210.000000       6210.000000  6210.000000         6210.0
# mean     34.283575   757.338164          9.897585     2.605636            1.0
# std       8.500013   353.687719          7.250603     0.925229            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      28.000000   469.000000          4.000000     2.000000            1.0
# 50%      33.000000   733.000000          8.000000     3.000000            1.0
# 75%      40.000000  1032.000000         15.000000     3.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     6210.000000              6210.000000  6210.000000     6210.000000
# mean      1020.317069                 2.258454    64.539130        2.319324
# std        540.216030                 0.987291    17.279755        0.723685
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        565.000000                 1.000000    51.000000        2.000000
# 50%       1017.000000                 2.000000    64.000000        2.000000
# 75%       1460.000000                 3.000000    78.000000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel          ...           RelationshipSatisfaction  \
# count  6210.000000          ...                        6210.000000
# mean      1.645733          ...                           2.346377
# std       0.926047          ...                           0.985966
# min       1.000000          ...                           1.000000
# 25%       1.000000          ...                           2.000000
# 50%       1.000000          ...                           2.000000
# 75%       2.000000          ...                           3.000000
# max       5.000000          ...                           4.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         6210.0       6210.000000        6210.000000
# mean            80.0          0.404992           8.776490
# std              0.0          0.683002           7.008011
# min             80.0          0.000000           0.000000
# 25%             80.0          0.000000           4.000000
# 50%             80.0          0.000000           7.000000
# 75%             80.0          1.000000          11.000000
# max             80.0          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            6210.000000      6210.000000     6210.000000
# mean                2.408213         2.419807        5.186957
# std                 1.081342         0.728209        5.536187
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        1.000000
# 50%                 2.000000         2.000000        4.000000
# 75%                 3.000000         3.000000        7.000000
# max                 6.000000         4.000000       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count         6210.000000              6210.000000           6210.000000
# mean             2.891626                 1.709823              2.836554
# std              2.916845                 2.690184              2.931249
# min              0.000000                 0.000000              0.000000
# 25%              1.000000                 0.000000              0.000000
# 50%              2.000000                 1.000000              2.000000
# 75%              4.000000                 2.000000              5.000000
# max             18.000000                15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
#Remove useless columns
ibm_df = copy.deepcopy(ibm_data)

for col in fields_trim_ibm:
    ibm_df = ibm_df.drop(col, 1)

# %%
# %matplotlib inline
# Employee Salaries by Job Roles
def salary_by_jobrole(df):
    for job in set(df.JobRole):
        agesalary = []
        for i in range(df['Age'].min(), df['Age'].max() + 1):
            agesalary.append([i, df[(df['Age'] == i) & (df['JobRole'] == job)]['MonthlyIncome'].median()])
        agesalary = pd.DataFrame(agesalary, columns=['Age '+job, 'Median Salary'])
        agesalary = agesalary.dropna().reset_index(drop=True)
    
        agesalary.plot(x='Age '+job, y='Median Salary', title=job)

salary_by_jobrole(ibm_data)

# %% [markdown]
# # Pairwise plots for IBM HR

# %%
# Pairwise plots
def att_to_cat(val):
    return 0 if val == "No" else 1

attritions = ibm_df.Attrition.values
ibm_df["Attritions"] = [att_to_cat(x) for x in attritions]

ibm_df.MaritalStatus = pd.Categorical(ibm_df.MaritalStatus).codes

# Out of 35 columns these have some relations (Mentioned in ibm_analysis.txt)

columns_to_plot = ['Attrition', 'YearsWithCurrManager', 'Age', 'YearsAtCompany', 'MonthlyIncome', 
                   'YearsInCurrentRole', 'TotalWorkingYears', 'WorkLifeBalance', 'StockOptionLevel',
                  'NumCompaniesWorked', 'JobLevel', 'YearsSinceLastPromotion', 'DistanceFromHome']


g = sns.pairplot(ibm_df[columns_to_plot], hue='Attrition')
plt.show()

# %% [markdown]
# # Pairwise plots for XYZ HR

# %%
xyz_df = copy.deepcopy(xyz_data)
xyz_df_cpy = copy.deepcopy(xyz_df)

def get_inc(sal):
    if sal == 'low':
        return 0
    elif sal == 'medium':
        return 1
    else:
        return 2

incomes = [get_inc(x) for x in xyz_df_cpy["salary"].values]
xyz_df_cpy["salary"] = incomes

g = sns.pairplot(xyz_df_cpy, hue='left')
plt.show()

# %% [markdown]
# # Employee Turnovers

# %%
# Overview of summary (Turnover V.S. Non-turnover)
turnover_Summary = xyz_df.groupby('left')
turnover_Summary.mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
turnover_Summary2 = ibm_df.groupby('Attrition')
turnover_Summary2.mean()
# Out:
#                  Age   DailyRate  DistanceFromHome  Education  \
# Attrition
# No         37.561233  812.504461          8.915653   2.927007
# Yes        33.471569  743.671288         10.140848   2.526020
#
#            EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# Attrition
# No                        2.771290   65.952149        2.770479  2.145985
# Yes                       2.131404   64.189070        2.207555  1.521800
#
#            JobSatisfaction  MaritalStatus     ...      \
# Attrition                                     ...
# No                2.778589       1.045418     ...
# Yes               2.112518       1.332530     ...
#
#            RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# Attrition
# No                         2.733982          0.845093          11.862936
# Yes                        2.250352          0.295961           8.011855
#
#            TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# Attrition
# No                      2.832928         2.781022        7.369019
# Yes                     2.302994         2.330319        4.646373
#
#            YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# Attrition
# No                   4.484185                 2.234388              4.367397
# Yes                  2.497087                 1.579867              2.457304
#
#            Attritions
# Attrition
# No                0.0
# Yes               1.0
#
# [2 rows x 25 columns]

# %% [markdown]
# # Correlation Matrix XYZ

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm as cm

def correlation_matrix(df):
    fig = plt.figure(figsize=(20, 10))
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Feature Correlation')
    labels=df.columns
    xlabels = [x[0:3].upper() for x in labels]
    ax1.set_xticklabels(xlabels,fontsize=10)
    ax1.set_yticklabels(labels,fontsize=9)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=np.arange(-0.75,1,0.1))
    plt.show()

correlation_matrix(xyz_df)

# %% [markdown]
# # Correlation Matrix IBM

# %%
corr = ibm_df.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

corr
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.008597         -0.000668   0.170907
# DailyRate                 0.008597   1.000000          0.026956   0.008480
# DistanceFromHome         -0.000668   0.026956          1.000000  -0.007486
# Education                 0.170907   0.008480         -0.007486   1.000000
# EnvironmentSatisfaction   0.035348  -0.009628         -0.049376  -0.011468
# HourlyRate                0.094593   0.064792         -0.014104   0.056477
# JobInvolvement            0.076234   0.064648          0.026921   0.116425
# JobLevel                  0.572351   0.017715          0.024219   0.168311
# JobSatisfaction           0.050180   0.030680         -0.030300   0.078915
# MaritalStatus            -0.103532  -0.052029         -0.051903  -0.023495
# MonthlyIncome             0.557914   0.024689          0.000890   0.154910
# MonthlyRate              -0.034587  -0.140824          0.035715   0.028891
# NumCompaniesWorked        0.259311   0.060018         -0.038265   0.015293
# PercentSalaryHike        -0.032976  -0.037685          0.056372  -0.025970
# PerformanceRating         0.026935  -0.005866          0.012861  -0.004801
# RelationshipSatisfaction  0.128931  -0.011988         -0.062151   0.025825
# StockOptionLevel          0.136957   0.034494          0.022979   0.097313
# TotalWorkingYears         0.626105   0.021114         -0.037225   0.165394
# TrainingTimesLastYear     0.012969  -0.034617         -0.102389  -0.009866
# WorkLifeBalance           0.049925   0.029944         -0.087514   0.041619
# YearsAtCompany            0.426981  -0.032116         -0.040669   0.107781
# YearsInCurrentRole        0.350705   0.008566         -0.021292   0.095879
# YearsSinceLastPromotion   0.324866  -0.027580         -0.033916   0.070294
# YearsWithCurrManager      0.344094   0.019252         -0.029720   0.111627
# Attritions               -0.191945  -0.077640          0.067412  -0.172898
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.035348    0.094593        0.076234
# DailyRate                               -0.009628    0.064792        0.064648
# DistanceFromHome                        -0.049376   -0.014104        0.026921
# Education                               -0.011468    0.056477        0.116425
# EnvironmentSatisfaction                  1.000000   -0.023765        0.149334
# HourlyRate                              -0.023765    1.000000        0.066984
# JobInvolvement                           0.149334    0.066984        1.000000
# JobLevel                                 0.011908    0.022003        0.072701
# JobSatisfaction                          0.085024   -0.052445        0.035597
# MaritalStatus                            0.004210   -0.010916       -0.034049
# MonthlyIncome                           -0.022048    0.011359        0.050336
# MonthlyRate                              0.005584   -0.012946       -0.015584
# NumCompaniesWorked                      -0.090776    0.044552       -0.066403
# PercentSalaryHike                        0.053706   -0.035918        0.043977
# PerformanceRating                        0.078450    0.037751        0.073866
# RelationshipSatisfaction                 0.076946    0.047903        0.070003
# StockOptionLevel                         0.025553    0.056252        0.139754
# TotalWorkingYears                        0.012471    0.031352        0.040084
# TrainingTimesLastYear                    0.089432    0.015293        0.040650
# WorkLifeBalance                          0.078676    0.032529        0.130657
# YearsAtCompany                           0.036389    0.032077        0.036552
# YearsInCurrentRole                       0.054413    0.025307        0.061337
# YearsSinceLastPromotion                  0.061472   -0.004506        0.022371
# YearsWithCurrManager                     0.061124    0.011559        0.114122
# Attritions                              -0.258563   -0.040705       -0.310319
#
#                           JobLevel  JobSatisfaction  MaritalStatus  \
# Age                       0.572351         0.050180      -0.103532
# DailyRate                 0.017715         0.030680      -0.052029
# DistanceFromHome          0.024219        -0.030300      -0.051903
# Education                 0.168311         0.078915      -0.023495
# EnvironmentSatisfaction   0.011908         0.085024       0.004210
# HourlyRate                0.022003        -0.052445      -0.010916
# JobInvolvement            0.072701         0.035597      -0.034049
# JobLevel                  1.000000         0.062822      -0.106530
# JobSatisfaction           0.062822         1.000000      -0.067135
# MaritalStatus            -0.106530        -0.067135       1.000000
# MonthlyIncome             0.942152         0.030075      -0.087113
# MonthlyRate               0.088259         0.136309      -0.000395
# NumCompaniesWorked        0.197050         0.017022      -0.034116
# PercentSalaryHike        -0.095101        -0.024879       0.032716
# PerformanceRating         0.049062         0.006509      -0.018642
# RelationshipSatisfaction  0.128420         0.114331      -0.038970
# StockOptionLevel          0.129352         0.080434      -0.379019
# TotalWorkingYears         0.797354         0.057012      -0.109484
# TrainingTimesLastYear    -0.030709         0.080220       0.020165
# WorkLifeBalance           0.110477         0.013717      -0.024700
# YearsAtCompany            0.611750         0.057625      -0.067740
# YearsInCurrentRole        0.538810         0.029419      -0.072337
# YearsSinceLastPromotion   0.432995         0.051055      -0.020522
# YearsWithCurrManager      0.470947         0.017752      -0.019803
# Attritions               -0.268899        -0.266261       0.157362
#
#                              ...      RelationshipSatisfaction  \
# Age                          ...                      0.128931
# DailyRate                    ...                     -0.011988
# DistanceFromHome             ...                     -0.062151
# Education                    ...                      0.025825
# EnvironmentSatisfaction      ...                      0.076946
# HourlyRate                   ...                      0.047903
# JobInvolvement               ...                      0.070003
# JobLevel                     ...                      0.128420
# JobSatisfaction              ...                      0.114331
# MaritalStatus                ...                     -0.038970
# MonthlyIncome                ...                      0.122008
# MonthlyRate                  ...                      0.018629
# NumCompaniesWorked           ...                      0.074608
# PercentSalaryHike            ...                     -0.070067
# PerformanceRating            ...                      0.003792
# RelationshipSatisfaction     ...                      1.000000
# StockOptionLevel             ...                      0.074825
# TotalWorkingYears            ...                      0.118264
# TrainingTimesLastYear        ...                      0.079448
# WorkLifeBalance              ...                      0.044414
# YearsAtCompany               ...                      0.124480
# YearsInCurrentRole           ...                      0.117946
# YearsSinceLastPromotion      ...                      0.065649
# YearsWithCurrManager         ...                      0.077381
# Attritions                   ...                     -0.195686
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.136957           0.626105
# DailyRate                         0.034494           0.021114
# DistanceFromHome                  0.022979          -0.037225
# Education                         0.097313           0.165394
# EnvironmentSatisfaction           0.025553           0.012471
# HourlyRate                        0.056252           0.031352
# JobInvolvement                    0.139754           0.040084
# JobLevel                          0.129352           0.797354
# JobSatisfaction                   0.080434           0.057012
# MaritalStatus                    -0.379019          -0.109484
# MonthlyIncome                     0.103228           0.798316
# MonthlyRate                      -0.104576          -0.008213
# NumCompaniesWorked                0.049373           0.244125
# PercentSalaryHike                -0.008895          -0.105887
# PerformanceRating                 0.049458           0.038270
# RelationshipSatisfaction          0.074825           0.118264
# StockOptionLevel                  1.000000           0.122147
# TotalWorkingYears                 0.122147           1.000000
# TrainingTimesLastYear             0.084904          -0.022643
# WorkLifeBalance                   0.157112           0.056608
# YearsAtCompany                    0.121000           0.685837
# YearsInCurrentRole                0.157609           0.544655
# YearsSinceLastPromotion           0.044861           0.475368
# YearsWithCurrManager              0.119709           0.529039
# Attritions                       -0.320748          -0.219228
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                    0.012969         0.049925
# DailyRate                             -0.034617         0.029944
# DistanceFromHome                      -0.102389        -0.087514
# Education                             -0.009866         0.041619
# EnvironmentSatisfaction                0.089432         0.078676
# HourlyRate                             0.015293         0.032529
# JobInvolvement                         0.040650         0.130657
# JobLevel                              -0.030709         0.110477
# JobSatisfaction                        0.080220         0.013717
# MaritalStatus                          0.020165        -0.024700
# MonthlyIncome                         -0.037566         0.099096
# MonthlyRate                           -0.044796        -0.014179
# NumCompaniesWorked                    -0.005562         0.012259
# PercentSalaryHike                      0.045407         0.037524
# PerformanceRating                      0.038857         0.099570
# RelationshipSatisfaction               0.079448         0.044414
# StockOptionLevel                       0.084904         0.157112
# TotalWorkingYears                     -0.022643         0.056608
# TrainingTimesLastYear                  1.000000         0.080951
# WorkLifeBalance                        0.080951         1.000000
# YearsAtCompany                         0.017596         0.064103
# YearsInCurrentRole                     0.034402         0.094972
# YearsSinceLastPromotion               -0.010154         0.012948
# YearsWithCurrManager                   0.041886         0.047014
# Attritions                            -0.195509        -0.246912
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.426981            0.350705
# DailyRate                      -0.032116            0.008566
# DistanceFromHome               -0.040669           -0.021292
# Education                       0.107781            0.095879
# EnvironmentSatisfaction         0.036389            0.054413
# HourlyRate                      0.032077            0.025307
# JobInvolvement                  0.036552            0.061337
# JobLevel                        0.611750            0.538810
# JobSatisfaction                 0.057625            0.029419
# MaritalStatus                  -0.067740           -0.072337
# MonthlyIncome                   0.611192            0.526839
# MonthlyRate                    -0.076011           -0.065549
# NumCompaniesWorked              0.034861            0.048491
# PercentSalaryHike              -0.090997           -0.039785
# PerformanceRating               0.038997            0.091292
# RelationshipSatisfaction        0.124480            0.117946
# StockOptionLevel                0.121000            0.157609
# TotalWorkingYears               0.685837            0.544655
# TrainingTimesLastYear           0.017596            0.034402
# WorkLifeBalance                 0.064103            0.094972
# YearsAtCompany                  1.000000            0.663595
# YearsInCurrentRole              0.663595            1.000000
# YearsSinceLastPromotion         0.540384            0.495673
# YearsWithCurrManager            0.632614            0.630004
# Attritions                     -0.196195           -0.271778
#
#                           YearsSinceLastPromotion  YearsWithCurrManager  \
# Age                                      0.324866              0.344094
# DailyRate                               -0.027580              0.019252
# DistanceFromHome                        -0.033916             -0.029720
# Education                                0.070294              0.111627
# EnvironmentSatisfaction                  0.061472              0.061124
# HourlyRate                              -0.004506              0.011559
# JobInvolvement                           0.022371              0.114122
# JobLevel                                 0.432995              0.470947
# JobSatisfaction                          0.051055              0.017752
# MaritalStatus                           -0.020522             -0.019803
# MonthlyIncome                            0.440205              0.469253
# MonthlyRate                             -0.065172             -0.134719
# NumCompaniesWorked                       0.060802             -0.000398
# PercentSalaryHike                       -0.084953             -0.032206
# PerformanceRating                        0.021101              0.086458
# RelationshipSatisfaction                 0.065649              0.077381
# StockOptionLevel                         0.044861              0.119709
# TotalWorkingYears                        0.475368              0.529039
# TrainingTimesLastYear                   -0.010154              0.041886
# WorkLifeBalance                          0.012948              0.047014
# YearsAtCompany                           0.540384              0.632614
# YearsInCurrentRole                       0.495673              0.630004
# YearsSinceLastPromotion                  1.000000              0.502484
# YearsWithCurrManager                     0.502484              1.000000
# Attritions                              -0.097062             -0.259962
#
#                           Attritions
# Age                        -0.191945
# DailyRate                  -0.077640
# DistanceFromHome            0.067412
# Education                  -0.172898
# EnvironmentSatisfaction    -0.258563
# HourlyRate                 -0.040705
# JobInvolvement             -0.310319
# JobLevel                   -0.268899
# JobSatisfaction            -0.266261
# MaritalStatus               0.157362
# MonthlyIncome              -0.214468
# MonthlyRate                 0.016996
# NumCompaniesWorked          0.002833
# PercentSalaryHike          -0.066023
# PerformanceRating          -0.206691
# RelationshipSatisfaction   -0.195686
# StockOptionLevel           -0.320748
# TotalWorkingYears          -0.219228
# TrainingTimesLastYear      -0.195509
# WorkLifeBalance            -0.246912
# YearsAtCompany             -0.196195
# YearsInCurrentRole         -0.271778
# YearsSinceLastPromotion    -0.097062
# YearsWithCurrManager       -0.259962
# Attritions                  1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# ## Summary:
#
#  From the heatmap, there is a positive(+) correlation between projectCount, averageMonthlyHours, and evaluation. Which could mean that the employees who spent more hours and did more projects were evaluated highly.
#
#  For the negative(-) relationships, turnover and satisfaction are highly correlated. I'm assuming that people tend to leave a company more when they are less satisfied.

# %% [markdown]
# ## Salary vs TurnOver
# ### XYZ HR

# %%
f, ax = plt.subplots(figsize=(15, 4))


sns.countplot(y="salary", hue='left', data=xyz_df_cpy).set_title('Employee Salary Turnover Distribution')
# Out:
# Text(0.5,1,u'Employee Salary Turnover Distribution')

# %% [markdown]
# ### IBM HR

# %%
import numpy as np

ibm_cpy = copy.deepcopy(ibm_df)
low_sal = ibm_cpy['MonthlyIncome']

a = np.array(ibm_cpy['MonthlyIncome'])
low_range = np.percentile(a, 33) 
medium_range = np.percentile(a, 66)


def cat_to_sal(sal):
    if sal <= low_range:
        return 'low'
    elif sal >= low_range and sal < medium_range:
        return 'medium'
    elif sal >= medium_range:
        return 'high'
    
incomes = [cat_to_sal(x) for x in ibm_cpy['MonthlyIncome'].values]
ibm_cpy["MonthlyIncome"] = incomes


f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(y="MonthlyIncome", hue='Attrition', data=ibm_cpy).set_title('Employee Salary Turnover Distribution for IBM')
# Out:
# Text(0.5,1,u'Employee Salary Turnover Distribution for IBM')

# %%
xyz_hist_cols = xyz_df.columns
def hr_hist(df, cols):    
    import matplotlib.pyplot as plt
    
    ## Loop over columns and plot histograms
    for col in cols:
        fig = plt.figure(figsize=(8, 6))
        fig.clf()
        ax = fig.gca()
        df[col].hist(bins = 30, ax = ax)
        ax.set_xlabel(col)
        ax.set_ylabel('Density of ' + col)
        ax.set_title('Density of ' + col) 
    
xyz_df.sales  = pd.Categorical(xyz_df.sales).codes
    
hr_hist(xyz_df, xyz_hist_cols)
