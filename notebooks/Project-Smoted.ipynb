# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import copy
# %matplotlib inline

sns.set(style="ticks", color_codes=True)


ibm_data = pd.read_csv("HR_IBM.csv")
xyz_data = pd.read_csv("organization.csv")

fields_trim_ibm = ['EmployeeCount', 'Over18', 'EmployeeNumber', 'StandardHours']

ibm_data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  6210.000000  6210.000000       6210.000000  6210.000000         6210.0
# mean     34.283575   757.338164          9.897585     2.605636            1.0
# std       8.500013   353.687719          7.250603     0.925229            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      28.000000   469.000000          4.000000     2.000000            1.0
# 50%      33.000000   733.000000          8.000000     3.000000            1.0
# 75%      40.000000  1032.000000         15.000000     3.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     6210.000000              6210.000000  6210.000000     6210.000000
# mean      1020.317069                 2.258454    64.539130        2.319324
# std        540.216030                 0.987291    17.279755        0.723685
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        565.000000                 1.000000    51.000000        2.000000
# 50%       1017.000000                 2.000000    64.000000        2.000000
# 75%       1460.000000                 3.000000    78.000000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel          ...           RelationshipSatisfaction  \
# count  6210.000000          ...                        6210.000000
# mean      1.645733          ...                           2.346377
# std       0.926047          ...                           0.985966
# min       1.000000          ...                           1.000000
# 25%       1.000000          ...                           2.000000
# 50%       1.000000          ...                           2.000000
# 75%       2.000000          ...                           3.000000
# max       5.000000          ...                           4.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         6210.0       6210.000000        6210.000000
# mean            80.0          0.404992           8.776490
# std              0.0          0.683002           7.008011
# min             80.0          0.000000           0.000000
# 25%             80.0          0.000000           4.000000
# 50%             80.0          0.000000           7.000000
# 75%             80.0          1.000000          11.000000
# max             80.0          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            6210.000000      6210.000000     6210.000000
# mean                2.408213         2.419807        5.186957
# std                 1.081342         0.728209        5.536187
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        1.000000
# 50%                 2.000000         2.000000        4.000000
# 75%                 3.000000         3.000000        7.000000
# max                 6.000000         4.000000       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count         6210.000000              6210.000000           6210.000000
# mean             2.891626                 1.709823              2.836554
# std              2.916845                 2.690184              2.931249
# min              0.000000                 0.000000              0.000000
# 25%              1.000000                 0.000000              0.000000
# 50%              2.000000                 1.000000              2.000000
# 75%              4.000000                 2.000000              5.000000
# max             18.000000                15.000000             17.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# # Remove useless Columns

# %%
ibm_df = copy.deepcopy(ibm_data)

for col in fields_trim_ibm:
    ibm_df = ibm_df.drop(col, 1)

# %% [markdown]
# # Employee Salaries by Job Roles

# %%
# %matplotlib inline
def salary_by_jobrole(df):
    fig, axes = plt.subplots(nrows=3, ncols=3)
    fig.subplots_adjust(hspace=.5)
    
    rows = cols = 0
        
    for job in set(df.JobRole):
        agesalary = []
        for i in range(df['Age'].min(), df['Age'].max() + 1):
            agesalary.append([i, df[(df['Age'] == i) & (df['JobRole'] == job)]['MonthlyIncome'].median()])
        agesalary = pd.DataFrame(agesalary, columns=['Age '+job, 'Median Salary'])
        agesalary = agesalary.dropna().reset_index(drop=True)
       
        agesalary.plot(x='Age '+job, y='Median Salary', title=job, ax=axes[rows,cols], figsize=(30,20))
        
        if cols == 2:
            cols = 0
            rows += 1
        else:
            cols += 1

salary_by_jobrole(ibm_data)

# %% [markdown]
# # Pairwise plots for IBM HR

# %%
def att_to_cat(val):
    return 0 if val == "No" else 1

ibm_df["Attrition"] = [att_to_cat(x) for x in ibm_df.Attrition.values]

ibm_df.MaritalStatus = pd.Categorical(ibm_df.MaritalStatus).codes

# Out of 35 columns these have some relations (Mentioned in ibm_analysis.txt)
columns_to_plot = ['Attrition', 'YearsWithCurrManager', 'Age', 'YearsAtCompany', 'MonthlyIncome', 
                   'YearsInCurrentRole', 'TotalWorkingYears', 'WorkLifeBalance', 'StockOptionLevel',
                  'NumCompaniesWorked', 'JobLevel', 'YearsSinceLastPromotion', 'DistanceFromHome']

g = sns.pairplot(ibm_df[columns_to_plot], hue='Attrition')
plt.show()

# %% [markdown]
# # Pairwise plots for XYZ HR

# %%
xyz_df = copy.deepcopy(xyz_data)
xyz_df_cpy = copy.deepcopy(xyz_df)

salary_map = {'low': 0, 'medium': 1, 'high': 2}

incomes = [salary_map[x] for x in xyz_df_cpy["salary"].values]
xyz_df_cpy["salary"] = incomes

g = sns.pairplot(xyz_df_cpy, hue='left')
plt.show()

# %% [markdown]
# # Comparing Attrition vs Other Values

# %%
def pairplots_attritions(df):
    columns = list(df.columns)
    yval = ''
    
    # Remove attrition from columns to plot on x axis
    if 'Attrition' in columns:
        columns.remove('Attrition')
        yval = 'Attrition'
    elif 'left' in columns:
        columns.remove('left')
        yval = 'left'
    
    pp = sns.pairplot(data=df,y_vars=[yval],x_vars=columns, hue=yval)
    pp.fig.set_size_inches(100, 5)
    plt.show()

pairplots_attritions(ibm_df)
pairplots_attritions(xyz_df_cpy)

# %% [markdown]
# # Employee Turnovers

# %%
turnover_Summary = xyz_df.groupby('left')
turnover_Summary.mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
turnover_Summary2 = ibm_df.groupby('Attrition')
turnover_Summary2.mean()
# Out:
#                  Age   DailyRate  DistanceFromHome  Education  \
# Attrition
# 0          37.561233  812.504461          8.915653   2.927007
# 1          33.471569  743.671288         10.140848   2.526020
#
#            EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# Attrition
# 0                         2.771290   65.952149        2.770479  2.145985
# 1                         2.131404   64.189070        2.207555  1.521800
#
#            JobSatisfaction  MaritalStatus          ...           \
# Attrition                                          ...
# 0                 2.778589       1.045418          ...
# 1                 2.112518       1.332530          ...
#
#            PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# Attrition
# 0                   3.153285                  2.733982          0.845093
# 1                   3.033153                  2.250352          0.295961
#
#            TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# Attrition
# 0                  11.862936               2.832928         2.781022
# 1                   8.011855               2.302994         2.330319
#
#            YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# Attrition
# 0                7.369019            4.484185                 2.234388
# 1                4.646373            2.497087                 1.579867
#
#            YearsWithCurrManager
# Attrition
# 0                      4.367397
# 1                      2.457304
#
# [2 rows x 24 columns]

# %% [markdown]
# # Correlation Matrix XYZ

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm as cm

def correlation_matrix(df):
    fig = plt.figure(figsize=(20, 10))
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Feature Correlation')
    labels=df.columns
    xlabels = [x[0:3].upper() for x in labels]
    ax1.set_xticklabels(xlabels,fontsize=10)
    ax1.set_yticklabels(labels,fontsize=9)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=np.arange(-0.75,1,0.1))
    plt.show()

correlation_matrix(xyz_df)

# %% [markdown]
# # Correlation Matrix IBM

# %%
corr = ibm_df.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

corr
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.191945   0.008597         -0.000668
# Attrition                -0.191945   1.000000  -0.077640          0.067412
# DailyRate                 0.008597  -0.077640   1.000000          0.026956
# DistanceFromHome         -0.000668   0.067412   0.026956          1.000000
# Education                 0.170907  -0.172898   0.008480         -0.007486
# EnvironmentSatisfaction   0.035348  -0.258563  -0.009628         -0.049376
# HourlyRate                0.094593  -0.040705   0.064792         -0.014104
# JobInvolvement            0.076234  -0.310319   0.064648          0.026921
# JobLevel                  0.572351  -0.268899   0.017715          0.024219
# JobSatisfaction           0.050180  -0.266261   0.030680         -0.030300
# MaritalStatus            -0.103532   0.157362  -0.052029         -0.051903
# MonthlyIncome             0.557914  -0.214468   0.024689          0.000890
# MonthlyRate              -0.034587   0.016996  -0.140824          0.035715
# NumCompaniesWorked        0.259311   0.002833   0.060018         -0.038265
# PercentSalaryHike        -0.032976  -0.066023  -0.037685          0.056372
# PerformanceRating         0.026935  -0.206691  -0.005866          0.012861
# RelationshipSatisfaction  0.128931  -0.195686  -0.011988         -0.062151
# StockOptionLevel          0.136957  -0.320748   0.034494          0.022979
# TotalWorkingYears         0.626105  -0.219228   0.021114         -0.037225
# TrainingTimesLastYear     0.012969  -0.195509  -0.034617         -0.102389
# WorkLifeBalance           0.049925  -0.246912   0.029944         -0.087514
# YearsAtCompany            0.426981  -0.196195  -0.032116         -0.040669
# YearsInCurrentRole        0.350705  -0.271778   0.008566         -0.021292
# YearsSinceLastPromotion   0.324866  -0.097062  -0.027580         -0.033916
# YearsWithCurrManager      0.344094  -0.259962   0.019252         -0.029720
#
#                           Education  EnvironmentSatisfaction  HourlyRate  \
# Age                        0.170907                 0.035348    0.094593
# Attrition                 -0.172898                -0.258563   -0.040705
# DailyRate                  0.008480                -0.009628    0.064792
# DistanceFromHome          -0.007486                -0.049376   -0.014104
# Education                  1.000000                -0.011468    0.056477
# EnvironmentSatisfaction   -0.011468                 1.000000   -0.023765
# HourlyRate                 0.056477                -0.023765    1.000000
# JobInvolvement             0.116425                 0.149334    0.066984
# JobLevel                   0.168311                 0.011908    0.022003
# JobSatisfaction            0.078915                 0.085024   -0.052445
# MaritalStatus             -0.023495                 0.004210   -0.010916
# MonthlyIncome              0.154910                -0.022048    0.011359
# MonthlyRate                0.028891                 0.005584   -0.012946
# NumCompaniesWorked         0.015293                -0.090776    0.044552
# PercentSalaryHike         -0.025970                 0.053706   -0.035918
# PerformanceRating         -0.004801                 0.078450    0.037751
# RelationshipSatisfaction   0.025825                 0.076946    0.047903
# StockOptionLevel           0.097313                 0.025553    0.056252
# TotalWorkingYears          0.165394                 0.012471    0.031352
# TrainingTimesLastYear     -0.009866                 0.089432    0.015293
# WorkLifeBalance            0.041619                 0.078676    0.032529
# YearsAtCompany             0.107781                 0.036389    0.032077
# YearsInCurrentRole         0.095879                 0.054413    0.025307
# YearsSinceLastPromotion    0.070294                 0.061472   -0.004506
# YearsWithCurrManager       0.111627                 0.061124    0.011559
#
#                           JobInvolvement  JobLevel  JobSatisfaction  \
# Age                             0.076234  0.572351         0.050180
# Attrition                      -0.310319 -0.268899        -0.266261
# DailyRate                       0.064648  0.017715         0.030680
# DistanceFromHome                0.026921  0.024219        -0.030300
# Education                       0.116425  0.168311         0.078915
# EnvironmentSatisfaction         0.149334  0.011908         0.085024
# HourlyRate                      0.066984  0.022003        -0.052445
# JobInvolvement                  1.000000  0.072701         0.035597
# JobLevel                        0.072701  1.000000         0.062822
# JobSatisfaction                 0.035597  0.062822         1.000000
# MaritalStatus                  -0.034049 -0.106530        -0.067135
# MonthlyIncome                   0.050336  0.942152         0.030075
# MonthlyRate                    -0.015584  0.088259         0.136309
# NumCompaniesWorked             -0.066403  0.197050         0.017022
# PercentSalaryHike               0.043977 -0.095101        -0.024879
# PerformanceRating               0.073866  0.049062         0.006509
# RelationshipSatisfaction        0.070003  0.128420         0.114331
# StockOptionLevel                0.139754  0.129352         0.080434
# TotalWorkingYears               0.040084  0.797354         0.057012
# TrainingTimesLastYear           0.040650 -0.030709         0.080220
# WorkLifeBalance                 0.130657  0.110477         0.013717
# YearsAtCompany                  0.036552  0.611750         0.057625
# YearsInCurrentRole              0.061337  0.538810         0.029419
# YearsSinceLastPromotion         0.022371  0.432995         0.051055
# YearsWithCurrManager            0.114122  0.470947         0.017752
#
#                                   ...           PerformanceRating  \
# Age                               ...                    0.026935
# Attrition                         ...                   -0.206691
# DailyRate                         ...                   -0.005866
# DistanceFromHome                  ...                    0.012861
# Education                         ...                   -0.004801
# EnvironmentSatisfaction           ...                    0.078450
# HourlyRate                        ...                    0.037751
# JobInvolvement                    ...                    0.073866
# JobLevel                          ...                    0.049062
# JobSatisfaction                   ...                    0.006509
# MaritalStatus                     ...                   -0.018642
# MonthlyIncome                     ...                    0.044540
# MonthlyRate                       ...                   -0.015956
# NumCompaniesWorked                ...                   -0.025188
# PercentSalaryHike                 ...                    0.484244
# PerformanceRating                 ...                    1.000000
# RelationshipSatisfaction          ...                    0.003792
# StockOptionLevel                  ...                    0.049458
# TotalWorkingYears                 ...                    0.038270
# TrainingTimesLastYear             ...                    0.038857
# WorkLifeBalance                   ...                    0.099570
# YearsAtCompany                    ...                    0.038997
# YearsInCurrentRole                ...                    0.091292
# YearsSinceLastPromotion           ...                    0.021101
# YearsWithCurrManager              ...                    0.086458
#
#                           RelationshipSatisfaction  StockOptionLevel  \
# Age                                       0.128931          0.136957
# Attrition                                -0.195686         -0.320748
# DailyRate                                -0.011988          0.034494
# DistanceFromHome                         -0.062151          0.022979
# Education                                 0.025825          0.097313
# EnvironmentSatisfaction                   0.076946          0.025553
# HourlyRate                                0.047903          0.056252
# JobInvolvement                            0.070003          0.139754
# JobLevel                                  0.128420          0.129352
# JobSatisfaction                           0.114331          0.080434
# MaritalStatus                            -0.038970         -0.379019
# MonthlyIncome                             0.122008          0.103228
# MonthlyRate                               0.018629         -0.104576
# NumCompaniesWorked                        0.074608          0.049373
# PercentSalaryHike                        -0.070067         -0.008895
# PerformanceRating                         0.003792          0.049458
# RelationshipSatisfaction                  1.000000          0.074825
# StockOptionLevel                          0.074825          1.000000
# TotalWorkingYears                         0.118264          0.122147
# TrainingTimesLastYear                     0.079448          0.084904
# WorkLifeBalance                           0.044414          0.157112
# YearsAtCompany                            0.124480          0.121000
# YearsInCurrentRole                        0.117946          0.157609
# YearsSinceLastPromotion                   0.065649          0.044861
# YearsWithCurrManager                      0.077381          0.119709
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                                0.626105               0.012969
# Attrition                         -0.219228              -0.195509
# DailyRate                          0.021114              -0.034617
# DistanceFromHome                  -0.037225              -0.102389
# Education                          0.165394              -0.009866
# EnvironmentSatisfaction            0.012471               0.089432
# HourlyRate                         0.031352               0.015293
# JobInvolvement                     0.040084               0.040650
# JobLevel                           0.797354              -0.030709
# JobSatisfaction                    0.057012               0.080220
# MaritalStatus                     -0.109484               0.020165
# MonthlyIncome                      0.798316              -0.037566
# MonthlyRate                       -0.008213              -0.044796
# NumCompaniesWorked                 0.244125              -0.005562
# PercentSalaryHike                 -0.105887               0.045407
# PerformanceRating                  0.038270               0.038857
# RelationshipSatisfaction           0.118264               0.079448
# StockOptionLevel                   0.122147               0.084904
# TotalWorkingYears                  1.000000              -0.022643
# TrainingTimesLastYear             -0.022643               1.000000
# WorkLifeBalance                    0.056608               0.080951
# YearsAtCompany                     0.685837               0.017596
# YearsInCurrentRole                 0.544655               0.034402
# YearsSinceLastPromotion            0.475368              -0.010154
# YearsWithCurrManager               0.529039               0.041886
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                              0.049925        0.426981            0.350705
# Attrition                       -0.246912       -0.196195           -0.271778
# DailyRate                        0.029944       -0.032116            0.008566
# DistanceFromHome                -0.087514       -0.040669           -0.021292
# Education                        0.041619        0.107781            0.095879
# EnvironmentSatisfaction          0.078676        0.036389            0.054413
# HourlyRate                       0.032529        0.032077            0.025307
# JobInvolvement                   0.130657        0.036552            0.061337
# JobLevel                         0.110477        0.611750            0.538810
# JobSatisfaction                  0.013717        0.057625            0.029419
# MaritalStatus                   -0.024700       -0.067740           -0.072337
# MonthlyIncome                    0.099096        0.611192            0.526839
# MonthlyRate                     -0.014179       -0.076011           -0.065549
# NumCompaniesWorked               0.012259        0.034861            0.048491
# PercentSalaryHike                0.037524       -0.090997           -0.039785
# PerformanceRating                0.099570        0.038997            0.091292
# RelationshipSatisfaction         0.044414        0.124480            0.117946
# StockOptionLevel                 0.157112        0.121000            0.157609
# TotalWorkingYears                0.056608        0.685837            0.544655
# TrainingTimesLastYear            0.080951        0.017596            0.034402
# WorkLifeBalance                  1.000000        0.064103            0.094972
# YearsAtCompany                   0.064103        1.000000            0.663595
# YearsInCurrentRole               0.094972        0.663595            1.000000
# YearsSinceLastPromotion          0.012948        0.540384            0.495673
# YearsWithCurrManager             0.047014        0.632614            0.630004
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.324866              0.344094
# Attrition                               -0.097062             -0.259962
# DailyRate                               -0.027580              0.019252
# DistanceFromHome                        -0.033916             -0.029720
# Education                                0.070294              0.111627
# EnvironmentSatisfaction                  0.061472              0.061124
# HourlyRate                              -0.004506              0.011559
# JobInvolvement                           0.022371              0.114122
# JobLevel                                 0.432995              0.470947
# JobSatisfaction                          0.051055              0.017752
# MaritalStatus                           -0.020522             -0.019803
# MonthlyIncome                            0.440205              0.469253
# MonthlyRate                             -0.065172             -0.134719
# NumCompaniesWorked                       0.060802             -0.000398
# PercentSalaryHike                       -0.084953             -0.032206
# PerformanceRating                        0.021101              0.086458
# RelationshipSatisfaction                 0.065649              0.077381
# StockOptionLevel                         0.044861              0.119709
# TotalWorkingYears                        0.475368              0.529039
# TrainingTimesLastYear                   -0.010154              0.041886
# WorkLifeBalance                          0.012948              0.047014
# YearsAtCompany                           0.540384              0.632614
# YearsInCurrentRole                       0.495673              0.630004
# YearsSinceLastPromotion                  1.000000              0.502484
# YearsWithCurrManager                     0.502484              1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# ## Summary:
#
#  From the heatmap, there is a positive(+) correlation between projectCount, averageMonthlyHours, and evaluation. Which could mean that the employees who spent more hours and did more projects were evaluated highly.
#
#  For the negative(-) relationships, turnover and satisfaction are highly correlated. I'm assuming that people tend to leave a company more when they are less satisfied.

# %% [markdown]
# ## Salary vs TurnOver
# ### XYZ HR

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(y="salary", hue='left', data=xyz_df_cpy).set_title('Employee Salary Turnover Distribution')
# Out:
# Text(0.5,1,u'Employee Salary Turnover Distribution')

# %% [markdown]
# ### IBM HR

# %%
import numpy as np

ibm_cpy = copy.deepcopy(ibm_df)
low_sal = ibm_cpy['MonthlyIncome']

a = np.array(ibm_cpy['MonthlyIncome'])
low_range = np.percentile(a, 33) 
medium_range = np.percentile(a, 66)


def cat_to_sal(sal):
    if sal <= low_range:
        return 'low'
    elif sal >= low_range and sal < medium_range:
        return 'medium'
    elif sal >= medium_range:
        return 'high'
    
incomes = [cat_to_sal(x) for x in ibm_cpy['MonthlyIncome'].values]
ibm_cpy["MonthlyIncome"] = incomes


f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(y="MonthlyIncome", hue='Attrition', data=ibm_cpy).set_title('Employee Salary Turnover Distribution for IBM')
# Out:
# Text(0.5,1,u'Employee Salary Turnover Distribution for IBM')

# %% [markdown]
# # Histogram Plots

# %%
import matplotlib.pyplot as plt

xyz_df.sales  = pd.Categorical(xyz_df.sales).codes

def hr_hist(df):    
    rowval = colval = 0
    fig, axes = plt.subplots(nrows=4, ncols=3)
    fig.subplots_adjust(hspace=.5)
    
    
    cols = df.columns
    ## Loop over columns and plot histograms
    for col in cols:
        data_plot = df[col].hist(bins = 30, ax = axes[rowval,colval], figsize=(30,20))
        
        data_plot.set_xlabel(col)
        data_plot.set_ylabel('Density of ' + col)
        data_plot.set_title('Density of ' + col)
        
        if colval == 2:
            colval = 0
            rowval += 1
        else:
            colval += 1

    fig.delaxes(axes[3][1])
    fig.delaxes(axes[3][2])
        
hr_hist(xyz_df)
hr_hist(ibm_df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-140-037efc6470c9> in <module>()
#      28
#      29 hr_hist(xyz_df)
# ---> 30 hr_hist(ibm_df)
#
# <ipython-input-140-037efc6470c9> in hr_hist(df)
#      12     ## Loop over columns and plot histograms
#      13     for col in cols:
# ---> 14         data_plot = df[col].hist(bins = 30, ax = axes[rowval,colval], figsize=(30,20))
#      15
#      16         data_plot.set_xlabel(col)
#
# IndexError: index 4 is out of bounds for axis 0 with size 4
